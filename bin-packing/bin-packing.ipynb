# %%
from Item import Item
from Packing import Packing

# 10 items: a: 2, b: 6, c: 2
a = 12 #a 5x4x3
b = 12 #b 3x3x3
c = 6 #c 6x2x2

items = [Item("a", 5, 4, 3)] * a + [Item("b", 3, 3, 3)] * b + [Item("c", 6, 2, 2)] * c

bin_packing = Packing(items)

# %%
import matplotlib.pyplot as plt
import numpy as np

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import


# prepare some coordinates
x, y, z = np.indices((12, 9, 6))

# First Set
cube1 = ((x >= 0) & (x < 3)) & (y < 3) & (z < 3)
cube2 = ((x >= 3) & (x < 6)) & (y < 3) & (z < 3)
cube3 = ((x >= 6) & (x < 9)) & (y < 3) & (z < 3)
cube4 = ((x >= 9) & (x < 12)) & (y < 3) & (z < 3)
# Second Set
cube5 = ((x >= 0) & (x < 3)) & ((y >= 3) & (y < 6)) & (z < 3)
cube6 = ((x >= 3) & (x <= 6)) & ((y >= 3) & (y < 6)) & (z < 3)
cube7 = ((x >= 6) & (x <= 9)) &((y >= 3) & (y < 6)) & (z < 3)
cube8 = ((x >= 9) & (x <= 12)) & ((y >= 3) & (y < 6)) & (z < 3)
# Third Set
cube9 = ((x >= 0) & (x < 3)) & ((y >= 6) & (y < 9)) & (z < 3)
cube10 = ((x >= 3) & (x <= 6)) & ((y >= 6) & (y < 9)) & (z < 3)
cube11 = ((x >= 6) & (x <= 9)) &((y >= 6) & (y < 9)) & (z < 3)
cube12 = ((x >= 9) & (x <= 12)) & ((y >= 6) & (y < 9)) & (z < 3)

# %%
# combine the objects into a single boolean array
voxels = cube1 | cube2 | cube3 | cube4 
voxels += cube5 | cube6 | cube7 | cube8
voxels += cube9 | cube10 | cube11 | cube12
# set the colors of each object
colors = np.empty(voxels.shape, dtype=object)
colors[cube1] = 'blue'
colors[cube2] = 'red'
colors[cube3] = 'purple'
colors[cube4] = 'green'
colors[cube5] = 'purple'
colors[cube6] = 'green'
colors[cube7] = 'red'
colors[cube8] = 'blue'
colors[cube9] = 'blue'
colors[cube10] = 'red'
colors[cube11] = 'purple'
colors[cube12] = 'green'
# and plot everything
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.voxels(voxels, facecolors=colors, edgecolor='k')
# Axises
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
#Plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import


# prepare some coordinates
x, y, z = np.indices((12, 9, 6))

#a width = 5 length = 4 height = 3

# wxhxl 5x3x4
# hxwxl 3x5x4
# hxlxw 3x4x5
# lxhxw 4x3x5
# lxwxh 4x5x3
# wxlxh 5x4x3

# First Set
cube1 = ((x >= 0) & (x < 4)) & (y < 5) & (z < 3)


# combine the objects into a single boolean array
voxels = cube1
# set the colors of each object
colors = np.empty(voxels.shape, dtype=object)
colors[cube1] = 'blue'
# and plot everything
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.voxels(voxels, facecolors=colors, edgecolor='k')
# Axises
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
#Plot
plt.show()
